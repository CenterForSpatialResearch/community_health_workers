# %%
import geopandas as gpd

# %%
tracts = gpd.read_file("data/svi/svi_2018_tracts_state_ranked.geojson")

# %%
tracts.head()
# Out:
#    ST    STATE ST_ABBR STCNTY   COUNTY         FIPS  \
# 0  01  ALABAMA      AL  01015  Calhoun  01015981901
# 1  01  ALABAMA      AL  01015  Calhoun  01015981902
# 2  01  ALABAMA      AL  01015  Calhoun  01015981903
# 3  01  ALABAMA      AL  01097   Mobile  01097003605
# 4  01  ALABAMA      AL  01097   Mobile  01097990000
#
#                                         LOCATION  AREA_SQMI  E_TOTPOP  \
# 0  Census Tract 9819.01, Calhoun County, Alabama  24.243865         0
# 1  Census Tract 9819.02, Calhoun County, Alabama  34.646714         0
# 2  Census Tract 9819.03, Calhoun County, Alabama  13.926276         0
# 3     Census Tract 36.05, Mobile County, Alabama   0.732300       899
# 4      Census Tract 9900, Mobile County, Alabama   0.000000         0
#
#    M_TOTPOP  ...  MP_UNINSUR  E_DAYPOP  Shape_STAr  Shape_STLe  \
# 0        12  ...         NaN     656.0    0.006105    0.339400
# 1        12  ...         NaN     146.0    0.008752    0.420459
# ...

# %%
tracts.columns
# Out:
# Index(['ST', 'STATE', 'ST_ABBR', 'STCNTY', 'COUNTY', 'FIPS', 'LOCATION',
#        'AREA_SQMI', 'E_TOTPOP', 'M_TOTPOP',
#        ...
#        'MP_UNINSUR', 'E_DAYPOP', 'Shape_STAr', 'Shape_STLe',
#        'RPL_ThemesStates', 'RPL_Theme1States', 'RPL_Theme2States',
#        'RPL_Theme3States', 'RPL_Theme4States', 'geometry'],
#       dtype='object', length=132)

# %%
sel_col = ['COUNTY', 'FIPS','RPL_ThemesStates','geometry']
sel_tracts = tracts[sel_col]

# %%
sel_tracts.to_file("data/svi/sm_svi_2018_tracts_state_ranked.geojson", driver='GeoJSON')
